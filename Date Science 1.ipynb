# %%
import os
osname = os.name
print(osname)
import platform
osplatform = platform.system()
print(osplatform)

import sys
import io
import pandas as pd
import numpy as np
from pathlib import Path
# Out:
# posix
# Linux

# %%
os.access(C:\, R_OK)
root = os.chroot("c:\")
# Out:
#   File "<ipython-input-6-bf803bcbde7f>", line 1
#     os.access(C:\, R_OK)
#                ^
# SyntaxError: invalid syntax

# %%
# os.access()
# Purepath
# p = Path('%SystemRoot%')
# p
Path.exists().real
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-30-99f7dc3c1050> in <module>
#       3 # p = Path('%SystemRoot%')
#       4 # p
# ----> 5 Path.exists().real
#
# TypeError: exists() missing 1 required positional argument: 'self'

# %%
# p.PureWindowsPath('c:/').root
sys.version
# Out:
# '3.7.9 (default, Aug 31 2020, 12:42:55) \n[GCC 7.3.0]'

# %%
# Path.root.fget(operator.attrgetter('_root'))
sr =os.getenv('_root')
print(sr)
# Out:
# None

# %%
pd.io()

# %%
import inspect
inspect.getclasstree(*)
# Out:
#   File "<ipython-input-50-d0f66f01de90>", line 2
#     inspect.getclasstree(*)
#                           ^
# SyntaxError: invalid syntax

# %%
# mods = help('modules')
# mods
help('To*')
# dir(pd)
# Out:
# No Python documentation found for 'To*'.
# Use help() to get the interactive help utility.
# Use help(str) for help on the str class.

# %%
os.access()
# Out:
# ['/home/wsuser/work',
#  '/opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ibm_watson_machine_learning/libs',
#  '/opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ibm_watson_machine_learning/tools',
#  '/opt/conda/envs/Python-3.7-main/lib/python37.zip',
#  '/opt/conda/envs/Python-3.7-main/lib/python3.7',
#  '/opt/conda/envs/Python-3.7-main/lib/python3.7/lib-dynload',
#  '',
#  '/home/wsuser/.local/lib/python3.7/site-packages',
#  '/opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages',
#  '/opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/IPython/extensions',
#  '/home/wsuser/.ipython',
#  '/opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/arcgis/learn/models/_inferencing/..',
#  '/opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/arcgis/learn/models/_inferencing',
#  '..']
